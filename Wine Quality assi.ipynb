# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import seaborn as sns

# %%
wt= pd.read_csv("WineQT.csv")

# %%
wt
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
wt.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
wt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
wt.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
wt.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
from sklearn.utils import resample

# %%
import matplotlib.pyplot as plt

# %%
Imbalance_values = wt['quality'].value_counts()

# %%
Imbalance_values
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
Imbalance_values.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Class Imbalance in Quality')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

# %%
### Balancing Imbalances
wt_class_0 = wt[wt.quantity == 5]
wt_class_1 = wt[wt.quantity == 6]
wt_class_2 = wt[wt.quantity == 7]
wt_class_3 = wt[wt.quantity == 4]
wt_class_4 = wt[wt.quantity == 8]
wt_class_5 = wt[wt.quantity == 3]

majority_class = wt_class_2.shape[0]



(wt_minority,  replace=True, n_samples= len(wt_majority),random_state=123)
# Out:
#   Cell In[41], line 13
#     (wt_minority,  replace=True, n_samples= len(wt_majority),random_state=123)
#                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
wt.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
x = wt.drop("quality", axis = 1)
y = wt["quality"]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
x= wt[["fixed acidity", "citric acid", "free sulfur dioxide", "total sulfur dioxide","density", "alcohol"]]

# %%
x
# Out:
#       fixed acidity  citric acid  free sulfur dioxide  total sulfur dioxide  \
# 0               7.4         0.00                 11.0                  34.0
# 1               7.8         0.00                 25.0                  67.0
# 2               7.8         0.04                 15.0                  54.0
# 3              11.2         0.56                 17.0                  60.0
# 4               7.4         0.00                 11.0                  34.0
# ...             ...          ...                  ...                   ...
# 1138            6.3         0.13                 29.0                  40.0
# 1139            6.8         0.08                 28.0                  38.0
# 1140            6.2         0.08                 32.0                  44.0
# 1141            5.9         0.10                 39.0                  51.0
# 1142            5.9         0.12                 32.0                  44.0
#
#       density  alcohol
# 0     0.99780      9.4
# ...

# %%
x.columns = x.columns.astype(str)
x_columns = x.columns

# %%
x_columns
# Out:
# Index(['fixed acidity', 'citric acid', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'alcohol'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
sk = MinMaxScaler()
x = sk.fit_transform(x)

# %%
x
# Out:
# array([[0.24778761, 0.        , 0.14925373, 0.09893993, 0.56754772,
#         0.15384615],
#        [0.28318584, 0.        , 0.35820896, 0.2155477 , 0.49412628,
#         0.21538462],
#        [0.28318584, 0.04      , 0.20895522, 0.16961131, 0.50881057,
#         0.21538462],
#        ...,
#        [0.14159292, 0.08      , 0.46268657, 0.13427562, 0.35462555,
#         0.32307692],
#        [0.11504425, 0.1       , 0.56716418, 0.1590106 , 0.37077827,
#         0.43076923],
#        [0.11504425, 0.12      , 0.46268657, 0.13427562, 0.39647577,
#         0.27692308]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state = 50)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

# %%
knn = KNN(n_neighbors = 45)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=45)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import f1_score

# %%
predicted_output = knn.predict(x_test)

# %%
accuracy_score(predicted_output, y_test)
# Out:
# 0.548951048951049

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
MSE(predicted_output, y_test)
# Out:
# np.float64(0.6433566433566433)

# %%
accuracy_list = []
k_values = []
for i in range (1,100):
    lnn = KNN(n_neighbors = i)
    lnn.fit(x_train, y_train)
    predicted_output = lnn.predict(x_test)
    accuracy= accuracy_score(predicted_output, y_test)
    k_values.append(i)
    accuracy_list.append(accuracy)

# %%
accuracy_list
# Out:
# [0.5524475524475524,
#  0.5384615384615384,
#  0.5174825174825175,
#  0.541958041958042,
#  0.548951048951049,
#  0.5559440559440559,
#  0.5454545454545454,
#  0.5384615384615384,
#  0.5524475524475524,
#  0.5524475524475524,
#  0.5524475524475524,
#  0.548951048951049,
#  0.548951048951049,
#  0.5314685314685315,
#  0.5174825174825175,
#  0.534965034965035,
#  0.5209790209790209,
#  0.5384615384615384,
#  0.5594405594405595,
#  0.5629370629370629,
#  0.5629370629370629,
#  0.5524475524475524,
#  0.5454545454545454,
#  0.5559440559440559,
#  0.5559440559440559,
#  0.5524475524475524,
#  0.5454545454545454,
#  0.5559440559440559,
#  0.5524475524475524,
#  0.5559440559440559,
#  0.5559440559440559,
#  0.5594405594405595,
#  0.5594405594405595,
#  0.5559440559440559,
#  0.5629370629370629,
#  0.5594405594405595,
#  0.5629370629370629,
#  0.5629370629370629,
#  0.5524475524475524,
#  0.5559440559440559,
#  0.5454545454545454,
#  0.548951048951049,
#  0.548951048951049,
# ...

# %%
plt.plot(k_values, accuracy_list)
plt.xlabel("Class_values")
plt.ylabel("accuracy_list")
plt.xticks()
plt.grid()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# %%
# Confussion method

# %%
cf = confusion_matrix(y_test, predicted_output)
cf
# Out:
# array([[  0,   0,   1,   1,   0,   0],
#        [  0,   0,   8,   5,   0,   0],
#        [  0,   0, 102,  25,   0,   0],
#        [  0,   0,  44,  53,   0,   0],
#        [  0,   0,   5,  41,   0,   0],
#        [  0,   0,   0,   1,   0,   0]])

# %%
sns.heatmap(cf, annot = True, cmap = "Blues", fmt="d")
# Out:
# <Axes: >

# %%
sns.heatmap(cf, annot = True, cmap = "Blues", fmt= "d", yticklabels= ["true 0", "true 1"], xticklabels= ["predicted 0", "predicted 1"])
plt.show()
