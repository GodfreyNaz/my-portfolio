# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sk = pd.read_csv("data.csv")

# %%
sk.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# !pip install pandas_profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
# ...

# %%
sk.city.unique()
# Out:
# array(['Shoreline', 'Seattle', 'Kent', 'Bellevue', 'Redmond',
#        'Maple Valley', 'North Bend', 'Lake Forest Park', 'Sammamish',
#        'Auburn', 'Des Moines', 'Bothell', 'Federal Way', 'Kirkland',
#        'Issaquah', 'Woodinville', 'Normandy Park', 'Fall City', 'Renton',
#        'Carnation', 'Snoqualmie', 'Duvall', 'Burien', 'Covington',
#        'Inglewood-Finn Hill', 'Kenmore', 'Newcastle', 'Mercer Island',
#        'Black Diamond', 'Ravensdale', 'Clyde Hill', 'Algona', 'Skykomish',
#        'Tukwila', 'Vashon', 'Yarrow Point', 'SeaTac', 'Medina',
#        'Enumclaw', 'Snoqualmie Pass', 'Pacific', 'Beaux Arts Village',
#        'Preston', 'Milton'], dtype=object)

# %%
### Check for dublicated Values!
sk.duplicated().sum()
# Out:
# np.int64(0)

# %%
sk.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
sk.drop("street", axis = 1, inplace = True)

# %%
sk.drop("city", axis = 1, inplace = True)
sk.drop("statezip", axis = 1, inplace = True)
sk.drop("country", axis = 1, inplace = True)

# %%
sk.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992

# %%
sk.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
## feauter Selction!

# %%
sk = sk[["price","bedrooms", "bathrooms", "sqft_living", "floors", "sqft_above"]]

# %%
sk.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  floors  sqft_above
# 0   313000.0       3.0       1.50         1340     1.5        1340
# 1  2384000.0       5.0       2.50         3650     2.0        3370
# 2   342000.0       3.0       2.00         1930     1.0        1930
# 3   420000.0       3.0       2.25         2000     1.0        1000
# 4   550000.0       4.0       2.50         1940     1.0        1140

# %%
import seaborn as sns

# %%
sns.pairplot(sk)

# %%
## Checking for Outliers
plt.figure(figsize = (7,7))
plt.subplot(2,2,1)
plt.boxplot(sk.bedrooms)
plt.xlabel("bedrooms")
plt.subplot(2,2,2)
plt.boxplot(sk.bathrooms)
plt.xlabel("bathrooms")
plt.subplot(2,2,3)
plt.boxplot(sk.sqft_living)
plt.xlabel("sqft_living")
plt.subplot(2,2,4)
plt.boxplot(sk.sqft_above)
plt.xlabel("sqft_above")
plt.show()

# %%
a = sk.bedrooms < 5
b = sk.bedrooms > 1.5
sk = sk[a & b]

# %%
c = sk.bathrooms < 3.8
d = sk.bathrooms > 0.2
sk = sk[c & d]

# %%
e= sk.sqft_living < 3850
sk = sk[e]

# %%
f= sk.sqft_above > 3500
f = sk[f]

# %%
## Checking for Outliers
plt.figure(figsize = (7,7))
plt.subplot(2,2,1)
plt.boxplot(sk.bedrooms)
plt.xlabel("bedrooms")
plt.subplot(2,2,2)
plt.boxplot(sk.bathrooms)
plt.xlabel("bathrooms")
plt.subplot(2,2,3)
plt.boxplot(sk.sqft_living)
plt.xlabel("sqft_living")
plt.subplot(2,2,4)
plt.boxplot(sk.sqft_above)
plt.xlabel("sqft_above")
plt.show()

# %%
sk.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  floors  sqft_above
# 0  313000.0       3.0       1.50         1340     1.5        1340
# 2  342000.0       3.0       2.00         1930     1.0        1930
# 3  420000.0       3.0       2.25         2000     1.0        1000
# 4  550000.0       4.0       2.50         1940     1.0        1140
# 5  490000.0       2.0       1.00          880     1.0         880

# %%
X= sk.drop("price", axis = 1)
X
# Out:
#       bedrooms  bathrooms  sqft_living  floors  sqft_above
# 0          3.0       1.50         1340     1.5        1340
# 2          3.0       2.00         1930     1.0        1930
# 3          3.0       2.25         2000     1.0        1000
# 4          4.0       2.50         1940     1.0        1140
# 5          2.0       1.00          880     1.0         880
# ...        ...        ...          ...     ...         ...
# 4595       3.0       1.75         1510     1.0        1510
# 4596       3.0       2.50         1460     2.0        1460
# 4597       3.0       2.50         3010     2.0        3010
# 4598       4.0       2.00         2090     1.0        1070
# 4599       3.0       2.50         1490     2.0        1490
#
# [3966 rows x 5 columns]

# %%
Y = sk["price"]

# %%
Y
# Out:
# 0       313000.000000
# 2       342000.000000
# 3       420000.000000
# 4       550000.000000
# 5       490000.000000
#             ...
# 4595    308166.666667
# 4596    534333.333333
# 4597    416904.166667
# 4598    203400.000000
# 4599    220600.000000
# Name: price, Length: 3966, dtype: float64

# %%
print (X.shape)
print (Y.shape)
# Out:
# (3966, 5)
# (3966,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Initialize the linear Regression model
LR = LinearRegression()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state = 10)

# %%
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
LR.predict(X_test)
# Out:
# array([394523.50193562, 397663.87362097, 399993.21632297, 549612.43024892,
#        462274.93194671, 917295.52474999, 599916.64454733, 606618.8396169 ,
#        504597.51573799, 622900.39453038, 581447.34499663, 304846.15702676,
#        380986.30393331, 888932.26767953, 536811.93759512, 549082.9526365 ,
#        598439.3098056 , 473446.56067723, 491311.32150773, 404281.3540434 ,
#        406328.27060967, 547388.45904188, 525066.68140074, 665732.3375868 ,
#        563958.09615996, 495591.1801339 , 486567.19060124, 532018.46008293,
#        508885.65345842, 419086.50073092, 299993.1670349 , 340350.20976527,
#        255473.16910081, 657035.31205655, 733852.17116079, 444734.54184135,
#        514401.3996675 , 610091.39160731, 589137.81935075, 606766.60127572,
#        299694.30457549, 570558.32663527, 549152.94947244, 398617.33506817,
#        552293.3211578 , 488614.19928423, 557817.34646114, 332549.52750742,
# ...

# %%
Y_test
# Out:
# 3277     365500.0
# 2225     375500.0
# 3207     600000.0
# 4024     437000.0
# 4124     375000.0
#           ...
# 2120     368000.0
# 123      309950.0
# 1386    1600000.0
# 4149     405000.0
# 3506     216500.0
# Name: price, Length: 992, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
predicted_values = LR.predict(X_test)

# %%
mean_squared_error(Y_test, predicted_values)
# Out:
# np.float64(41623201211.90499)

# %%
## Intercept Model
LR.intercept_
# Out:
# np.float64(175732.35610900883)

# %%
plt.scatter(Y_test, predicted_values)
plt.plot(Y_test, Y_test, c = "red")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %%
LR.predict([[3.0,2.00,1930,1.0,1930]])
# Out:
# C:\Users\HP\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([500963.16338192])
