# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df["species"].value_counts()
spec =
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df.species, label = ['setosa', 'versicolor', 'virginica'])
plt.show()

# %%
sns.countplot(df.species, palette = ['blue', 'pink', 'black'])
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16060\1680178678.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df.species, palette = ['blue', 'pink', 'black'])

# %%
### Checking For Outliners!!

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize = (6,6))
plt.subplot(2,2,1)
plt.boxplot(df.sepal_length)
plt.xlabel("sepal_length")
plt.subplot(2,2,2)
plt.boxplot(df.sepal_width)
plt.xlabel("sepal_width")
plt.subplot(2,2,3)
plt.boxplot(df.petal_length	)
plt.xlabel("petal_length")
plt.subplot(2,2,4)
plt.boxplot(df.petal_width)
plt.xlabel("petal_width")
plt.show()

# %%
### Removing or Handling Outliners

# %%
a = df["sepal_width"] > 2.3
b = df["sepal_width"] < 3.9
df = df[a & b]

# %%
plt.figure(figsize = (6,6))
plt.subplot(2,2,1)
plt.boxplot(df.sepal_length)
plt.xlabel("sepal_length")
plt.subplot(2,2,2)
plt.boxplot(df.sepal_width)
plt.xlabel("sepal_width")
plt.subplot(2,2,3)
plt.boxplot(df.petal_length	)
plt.xlabel("petal_length")
plt.subplot(2,2,4)
plt.boxplot(df.petal_width)
plt.xlabel("petal_width")
plt.show()

# %%
### Encoding

# %%
## Label Encoding
mydictionary ={"setosa": 0, "versicolor": 1, "virginica": 2}
df["species"].map(mydictionary)
G = mydictionary

# %%
df["species"] = df["species"].map(Mydictionary)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16060\2114306520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["species"] = df["species"].map(Mydictionary)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
X= df[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
Y= df["species"]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [136 rows x 4 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 136, dtype: int64

# %%
import numpy as np

# %% [markdown]
# ### K nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state = 20)

# %%
X.shape
# Out:
# (136, 4)

# %%
X_train.shape
# Out:
# (102, 4)

# %%
X_test.shape
# Out:
# (34, 4)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
### Checking for accuracy score

knn.score(X_test, Y_test)
# Out:
# 0.9705882352941176

# %%
knn = KNeighborsClassifier(n_neighbors= 7)
knn.fit(X_train, Y_train)
knn.score(X_test, Y_test)
# Out:
# 0.9411764705882353

# %%
n_neighbors = []
traning_accuracy = []
test_accuracy = []
range(10)
# Out:
# range(0, 10)

# %%
for i in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors= i)
    knn.fit(X_train, Y_train)
    b = knn.score(X_train, Y_train)
    a = knn.score(X_test, Y_test)
    traning_accuracy.append(b)
    test_accuracy.append(a)
    n_neighbors.append(i)

# %%
plt.plot(n_neighbors, traning_accuracy, '-ro', c= "red")
plt.plot(n_neighbors, test_accuracy, '-ro', c= "blue")
plt.xlabel("Number of K-neighbors")
plt.ylabel("Accuracy Score")
# plt.xticks(np.arange(1,100))
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16060\1557013491.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(n_neighbors, traning_accuracy, '-ro', c= "red")
# C:\Users\HP\AppData\Local\Temp\ipykernel_16060\1557013491.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(n_neighbors, test_accuracy, '-ro', c= "blue")

# %%
knn.predict([[4,3,1,1.9]])
# Out:
# C:\Users\HP\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([2])

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.species.unique()
# Out:
# array([0, 1, 2])

# %%
G
# Out:
# {'setosa': 0, 'versicolor': 1, 'virginica': 2}
