# %%
### Concatination
import pandas as pd

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])

df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])

pd.concat([df1, df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Daniel"], "Age": [10, 20]})
df2 = pd.DataFrame({"Name": ["Tobi", "Samuel"], "Age": [30, 40]})
df3 = pd.DataFrame({"Name": ["Joy", "Esther"], "Age": [50,60]})
df4 = pd.DataFrame({"Name": ["Victor", "Elijah"],"Age": [70, 80]})

# %%
c= pd.concat([df1,df2,df3,df4])

# %%
c
# Out:
#      Name  Age
# 0   Alice   10
# 1  Daniel   20
# 0    Tobi   30
# 1  Samuel   40
# 0     Joy   50
# 1  Esther   60
# 0  Victor   70
# 1  Elijah   80

# %%
c= pd.concat([df1,df2,df3,df4], axis =0)
c
# Out:
#      Name  Age
# 0   Alice   10
# 1  Daniel   20
# 0    Tobi   30
# 1  Samuel   40
# 0     Joy   50
# 1  Esther   60
# 0  Victor   70
# 1  Elijah   80

# %%
c= pd.concat([df1,df2,df3,df4], axis =1)
c
# Out:
#      Name  Age    Name  Age    Name  Age    Name  Age
# 0   Alice   10    Tobi   30     Joy   50  Victor   70
# 1  Daniel   20  Samuel   40  Esther   60  Elijah   80

# %%
pd.read_csv("outlet_size_high.xls")
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             NCD19        8.930          Low Fat         0.000000
# 1             FDO10       13.650          Regular         0.012741
# 2             FDF32       16.350          Low Fat         0.068024
# 3             FDN22       18.850          Regular         0.138190
# 4             DRJ59       11.650          low fat         0.019356
# ..              ...          ...              ...              ...
# 927           FDQ31        5.785          Regular         0.053802
# 928           FDJ32       10.695          Low Fat         0.057744
# 929           DRJ49        6.865          Low Fat         0.000000
# 930           FDR26       20.700          Low Fat         0.042801
# 931           FDF22        6.865          Low Fat         0.056783
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                Household   53.8614            OUT013  Supermarket Type1
# ...

# %%
pd.read_csv("outlet_size_medium.xls")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDP36       10.395          Regular         0.000000
# 4              FDP10          NaN          Low Fat         0.127470
# ...              ...          ...              ...              ...
# 2788           DRF37       17.250          Low Fat         0.084676
# 2789           FDF05       17.500          Low Fat         0.026980
# 2790           FDH24       20.700          Low Fat         0.021518
# 2791           NCJ19       18.600          Low Fat         0.118661
# 2792           FDN46        7.210          Regular         0.145221
#
#          Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0            Dairy  249.8092            OUT049  Supermarket Type1
# ...

# %%
pd.read_csv("outlet_size_small.xls")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA03        18.50          Regular         0.045464
# 1              FDS46        17.60          Regular         0.047257
# 2              FDP49         9.00          Regular         0.069089
# 3              FDU02        13.35          Low Fat         0.102492
# 4              NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 2383           FDN58        13.80          Regular         0.056862
# 2384           FDH31        12.00          Regular         0.020407
# 2385           FDF53        20.75              reg         0.083607
# 2386           NCJ29        10.60          Low Fat         0.035186
# 2387           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                  Dairy  144.1102            OUT046  Supermarket Type1
# ...

# %%
a = pd.read_csv("outlet_size_high.xls")
b = pd.read_csv("outlet_size_medium.xls")
c = pd.read_csv("outlet_size_small.xls")

# %%
d= pd.concat([a,b,c])

# %%
d
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              NCD19         8.93          Low Fat         0.000000
# 1              FDO10        13.65          Regular         0.012741
# 2              FDF32        16.35          Low Fat         0.068024
# 3              FDN22        18.85          Regular         0.138190
# 4              DRJ59        11.65          low fat         0.019356
# ...              ...          ...              ...              ...
# 2383           FDN58        13.80          Regular         0.056862
# 2384           FDH31        12.00          Regular         0.020407
# 2385           FDF53        20.75              reg         0.083607
# 2386           NCJ29        10.60          Low Fat         0.035186
# 2387           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# ...

# %%
a.shape
# Out:
# (932, 9)

# %%
b.shape
# Out:
# (2793, 9)

# %%
c.shape
# Out:
# (2388, 9)

# %%
f = pd.concat([a,b,c], axis=0, ignore_index =1)
f
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              NCD19         8.93          Low Fat         0.000000
# 1              FDO10        13.65          Regular         0.012741
# 2              FDF32        16.35          Low Fat         0.068024
# 3              FDN22        18.85          Regular         0.138190
# 4              DRJ59        11.65          low fat         0.019356
# ...              ...          ...              ...              ...
# 6108           FDN58        13.80          Regular         0.056862
# 6109           FDH31        12.00          Regular         0.020407
# 6110           FDF53        20.75              reg         0.083607
# 6111           NCJ29        10.60          Low Fat         0.035186
# 6112           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# ...

# %%
f.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6108           FDN58        13.80          Regular         0.056862
# 6109           FDH31        12.00          Regular         0.020407
# 6110           FDF53        20.75              reg         0.083607
# 6111           NCJ29        10.60          Low Fat         0.035186
# 6112           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 6108         Snack Foods  231.5984            OUT035  Supermarket Type1
# 6109                Meat   99.9042            OUT035  Supermarket Type1
# 6110        Frozen Foods  178.8318            OUT046  Supermarket Type1
# 6111  Health and Hygiene   85.1224            OUT035  Supermarket Type1
# 6112         Soft Drinks   75.4670            OUT046  Supermarket Type1
#
#       Item_Outlet_Sales
# 6108          7182.6504
# 6109           595.2252
# 6110          3608.6360
# ...

# %%
f.head(500)
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             NCD19        8.930          Low Fat         0.000000
# 1             FDO10       13.650          Regular         0.012741
# 2             FDF32       16.350          Low Fat         0.068024
# 3             FDN22       18.850          Regular         0.138190
# 4             DRJ59       11.650          low fat         0.019356
# ..              ...          ...              ...              ...
# 495           FDF53       20.750          Regular         0.083537
# 496           NCE42       21.100          Low Fat         0.010593
# 497           DRK47        7.905          Low Fat         0.064011
# 498           FDQ09        7.235          Low Fat         0.058084
# 499           DRE13        6.280          Low Fat         0.027682
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                Household   53.8614            OUT013  Supermarket Type1
# ...

# %%
f.groupby("Item_Fat_Content").agg({"Item_Outlet_Sales": "mean"})
# Out:
#                   Item_Outlet_Sales
# Item_Fat_Content
# LF                      2217.579774
# Low Fat                 2313.412342
# Regular                 2365.668861
# low fat                 2179.081202
# reg                     2086.950100

# %%
log = pd.read_csv("log.xls")

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
log.isnull()
# Out:
#      time   user  video  playback position  paused  volume
# 0   False  False  False              False   False   False
# 1   False  False  False              False    True    True
# 2   False  False  False              False    True    True
# 3   False  False  False              False    True    True
# 4   False  False  False              False    True    True
# 5   False  False  False              False    True    True
# 6   False  False  False              False    True    True
# 7   False  False  False              False    True    True
# 8   False  False  False              False    True    True
# 9   False  False  False              False    True    True
# 10  False  False  False              False    True    True
# 11  False  False  False              False    True    True
# 12  False  False  False              False    True    True
# 13  False  False  False              False   False   False
# 14  False  False  False              False    True    True
# ...

# %%
log.count()
# Out:
# time                 33
# user                 33
# video                33
# playback position    33
# paused                3
# volume                4
# dtype: int64

# %%
log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time               33 non-null     int64
#  1   user               33 non-null     object
#  2   video              33 non-null     object
#  3   playback position  33 non-null     int64
#  4   paused             3 non-null      object
#  5   volume             4 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
log.describe()
# Out:
#                time  playback position  volume
# count  3.300000e+01          33.000000    4.00
# mean   1.469976e+09          13.000000    8.75
# std    1.420109e+03          11.696688    2.50
# min    1.469974e+09           1.000000    5.00
# 25%    1.469975e+09           1.000000    8.75
# 50%    1.469975e+09          10.000000   10.00
# 75%    1.469977e+09          25.000000   10.00
# max    1.469978e+09          33.000000   10.00

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
log.agg({"volume":8.5])
# Out:
#   Cell In[186], line 1
#     log.agg({"volume":8.5])
#                          ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
log.fillna({"volume": 8.5})
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     8.5
# 2   1469974544  cheryl     intro.html                  9    NaN     8.5
# 3   1469974574  cheryl     intro.html                 10    NaN     8.5
# 4   1469977514     bob     intro.html                  1    NaN     8.5
# 5   1469977544     bob     intro.html                  1    NaN     8.5
# 6   1469977574     bob     intro.html                  1    NaN     8.5
# 7   1469977604     bob     intro.html                  1    NaN     8.5
# 8   1469974604  cheryl     intro.html                 11    NaN     8.5
# 9   1469974694  cheryl     intro.html                 14    NaN     8.5
# 10  1469974724  cheryl     intro.html                 15    NaN     8.5
# 11  1469974454     sue  advanced.html                 24    NaN     8.5
# ...

# %%
log["paused"].mean()
# Out:
# np.float64(0.3333333333333333)

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
log.fillna({"volume": 8.7}, inplace = True)

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     8.7
# 2   1469974544  cheryl     intro.html                  9    NaN     8.7
# 3   1469974574  cheryl     intro.html                 10    NaN     8.7
# 4   1469977514     bob     intro.html                  1    NaN     8.7
# 5   1469977544     bob     intro.html                  1    NaN     8.7
# 6   1469977574     bob     intro.html                  1    NaN     8.7
# 7   1469977604     bob     intro.html                  1    NaN     8.7
# 8   1469974604  cheryl     intro.html                 11    NaN     8.7
# 9   1469974694  cheryl     intro.html                 14    NaN     8.7
# 10  1469974724  cheryl     intro.html                 15    NaN     8.7
# 11  1469974454     sue  advanced.html                 24    NaN     8.7
# ...

# %%
log.fillna({"paused": 99}, inplace = True)

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6     99     8.7
# 2   1469974544  cheryl     intro.html                  9     99     8.7
# 3   1469974574  cheryl     intro.html                 10     99     8.7
# 4   1469977514     bob     intro.html                  1     99     8.7
# 5   1469977544     bob     intro.html                  1     99     8.7
# 6   1469977574     bob     intro.html                  1     99     8.7
# 7   1469977604     bob     intro.html                  1     99     8.7
# 8   1469974604  cheryl     intro.html                 11     99     8.7
# 9   1469974694  cheryl     intro.html                 14     99     8.7
# 10  1469974724  cheryl     intro.html                 15     99     8.7
# 11  1469974454     sue  advanced.html                 24     99     8.7
# ...

# %%
log.duplicated("paused")
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24    False
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# dtype: bool

# %%
log.describe()
# Out:
#                time  playback position     volume
# count  3.300000e+01          33.000000  33.000000
# mean   1.469976e+09          13.000000   8.706061
# std    1.420109e+03          11.696688   0.765645
# min    1.469974e+09           1.000000   5.000000
# 25%    1.469975e+09           1.000000   8.700000
# 50%    1.469975e+09          10.000000   8.700000
# 75%    1.469977e+09          25.000000   8.700000
# max    1.469978e+09          33.000000  10.000000

# %%
log.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# %%
df= pd.read_csv("Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
(df.isnull().sum())/891*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df.fillna({"Age": 29}, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
b= df.drop("Cabin", axis = 1)
b
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
b.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
(b.isnull().sum())/2*100
# Out:
# PassengerId      0.0
# Survived         0.0
# Pclass           0.0
# Name             0.0
# Sex              0.0
# Age              0.0
# SibSp            0.0
# Parch            0.0
# Ticket           0.0
# Fare             0.0
# Embarked       100.0
# dtype: float64

# %%
df.groupby("Embarked").count()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                 168       168     168   168  168  168    168    168     168
# Q                  77        77      77    77   77   77     77     77      77
# S                 644       644     644   644  644  644    644    644     644
#
#           Fare  Cabin
# Embarked
# C          168     69
# Q           77      4
# S          644    129

# %%
###c = chebourg
###s = southampton
###q = queenstown

# %%
df.replace({"embarked", ["C": "chebourg", "s": "southampton", "Q":"queenstown"})
# Out:
#   Cell In[34], line 1
#     df.replace({"embarked", ["C": "chebourg", "s": "southampton", "Q":"queenstown"})
#                                                                                   ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
df["embarked"] = df["Embarked"].replace ({"C":"chebourg", "S":"southampton","Q":"queenstown"})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data = {"name":["james", "john"],
       "gender":["f","m"]}

# %%
Data
# Out:
# {'name': ['james', 'john'], 'gender': ['f', 'm']}

# %%
Data = pd.DataFrame(Data)

# %%
Data
# Out:
#     name gender
# 0  james      f
# 1   john      m

# %%
Data["gender"] = Data["gender"].replace ({"f":"m", "m":"f"})

# %%
Data
# Out:
#     name gender
# 0  james      m
# 1   john      f

# %%
def addition (x,y):
    print (x+y)

# %%
addition (5,6)
# Out:
# 11

# %%
def Credential (Username,password):
    if (Username == "James" and password == 123):
        print ("Sucessful")
    elif (Username == "abc" and password == 000):
        print ("Reset Was Sucessfull")
    else:
        print ("Wrong")

# %%
Credential ("James", 123)
# Out:
# Sucessful

# %%
Credential ("abc",000)
# Out:
# Reset Was Sucessfull

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def catig (age):
    if age <= 18:
        return ("Minor")
    elif age <= 60:
        return ("adult")
    else:
        return ("Senior Citizen")

# %%
df["Age category"] = df["Age"].apply(catig)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as lib

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
## What is the survival rate amoung gendersdf

# %%
sr = df.groupby(["Sex", "Survived"]).agg({"PassengerId": "count"})

# %%
### groupby on works on aggregation functions like agg,mean,count,max,sum,mode

# %%
sr
# Out:
#                  PassengerId
# Sex    Survived
# female 0                  81
#        1                 233
# male   0                 468
#        1                 109

# %%
sr = df.groupby (["Sex", "Survived"]).agg({"PassengerId": "count"}).reset_index(["Sex", "Survived"])

# %%
sr
# Out:
#       Sex  Survived  PassengerId
# 0  female         0           81
# 1  female         1          233
# 2    male         0          468
# 3    male         1          109

# %%
###plt.
#Use pie chart for finding proportion a value a whole dataset
#use Scatered plot to find the relationship of data between two numerical datas
# Use Bar is to visualize categorical datas 
# historgram for numerical 
# Pivot tables are used to bring informations togther to visual in a different row entierly
line chat works best for numeric against numeric, trends and futurics.. ploting two numeric datas against each other
Bar chat or hsitogram for categorical against numeric

# %%
sr
# Out:
#       Sex  Survived  PassengerId
# 0  female         0           81
# 1  female         1          233
# 2    male         0          468
# 3    male         1          109

# %%
plt.plot(sr["PassengerId"], '-ro', sr["Survived"], "bs")
plt.ylabel("PassengerId")
plt.legend(["PassengerId", "Survived"])
plt.show()

# %%
### Distrubution of Passagner in each class
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a= df.groupby(["Pclass"]).agg({"PassengerId": "count"}).reset_index(["Pclass"])
a
# Out:
#    Pclass  PassengerId
# 0       1          216
# 1       2          184
# 2       3          491

# %%
plt.bar(a["Pclass"], a["PassengerId"])
plt.show()

# %%
### People who died and survied in each class

# %%
we = df.groupby (["Pclass", "Survived"]).agg({"PassengerId": "count"}).reset_index(["Pclass", "Survived"])

# %%
we
# Out:
#    Pclass  Survived  PassengerId
# 0       1         0           80
# 1       1         1          136
# 2       2         0           97
# 3       2         1           87
# 4       3         0          372
# 5       3         1          119
