# %%
import pandas as pd

# %%
pd.read_csv("WalmartSalesData.csv")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
c = pd.read_csv("WalmartSalesData.csv")

# %%
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
c.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       4
# Quantity         0
# Tax 5%           0
# Date             0
# Time             0
# Payment          0
# cogs             0
# Rating           0
# Gross Revenue    0
# Gross Profit     0
# dtype: int64

# %%
c.describe
# Out:
#        Unit price    Quantity       Tax 5%        cogs      Rating  \
# count  996.000000  998.000000  1000.000000  1000.00000  999.000000
# mean    55.605743    5.505010    15.379369   307.58738    6.971071
# std     26.491725    2.922859    11.708825   234.17651    1.718669
# min     10.080000    1.000000     0.508500    10.17000    4.000000
# 25%     32.777500    3.000000     5.924875   118.49750    5.500000
# 50%     55.055000    5.000000    12.088000   241.76000    7.000000
# 75%     77.772500    8.000000    22.445250   448.90500    8.500000
# max     99.960000   10.000000    49.650000   993.00000   10.000000
#
#        Gross Revenue  Gross Profit
# count     994.000000    994.000000
# mean      305.987243    250.421710
# std       233.592478    217.791224
# min        10.170000      0.000000
# 25%       116.652500     76.787500
# 50%       241.080000    186.505000
# 75%       448.560000    383.110000
# max       993.000000    893.700000

# %%
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
x = c.agg({"Branch": "mode", "City": "mode", "Gender": "mode", "Payment": "mode"})
y = c.agg({"Unit price": "mean", "Quantity": "mean", "Rating": "mean", "Gross Revenue": "mean", "Gross Profit": "mean"})
print(x)
print(y)
# Out:
#   Branch    City  Gender  Payment
# 0      A  Yangon  Female  Ewallet
# Unit price        55.605743
# Quantity           5.505000
# Rating             6.971000
# Gross Revenue    305.987260
# Gross Profit     250.151700
# dtype: float64

# %%
c["Gender"] = c["Gender"].replace("female", "Female")

# %%
c.fillna({"Branch": "A", "City": "Yangon", "Gender": "female", "Payment": "Ewallet"}, inplace = True)
c.fillna({"Unit Price": 55.61, "Quantity": 5.5, "Rating": 6.9, "Gross Revenue": 305.99, "Gross Profit": 205.42}, inplace = True)

# %%
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
c.fillna({"Unit price": 55.61}, inplace = True)

# %%
c.isnull().sum()
# Out:
# Invoice ID       0
# Branch           0
# City             0
# Customer type    0
# Gender           0
# Product line     0
# Unit price       0
# Quantity         0
# Tax 5%           0
# Date             0
# Time             0
# Payment          0
# cogs             0
# Rating           0
# Gross Revenue    0
# Gross Profit     0
# dtype: int64

# %%
c["Unit price"]
# Out:
# 0      74.69
# 1      15.28
# 2      46.33
# 3      58.22
# 4      86.31
#        ...
# 995    40.35
# 996    97.38
# 997    31.84
# 998    65.82
# 999    88.34
# Name: Unit price, Length: 1000, dtype: float64

# %%
## Null Percentage
(c.isnull().sum())/1000*100
# Out:
# Invoice ID       0.0
# Branch           0.0
# City             0.0
# Customer type    0.0
# Gender           0.0
# Product line     0.0
# Unit price       0.0
# Quantity         0.0
# Tax 5%           0.0
# Date             0.0
# Time             0.0
# Payment          0.0
# cogs             0.0
# Rating           0.0
# Gross Revenue    0.0
# Gross Profit     0.0
# dtype: float64

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   float64
#  8   Tax 5%         1000 non-null   float64
#  9   Date           1000 non-null   object
#  10  Time           1000 non-null   object
#  11  Payment        1000 non-null   object
#  12  cogs           1000 non-null   float64
#  13  Rating         1000 non-null   float64
#  14  Gross Revenue  1000 non-null   float64
#  15  Gross Profit   1000 non-null   float64
# dtypes: float64(7), object(9)
# memory usage: 125.1+ KB

# %%
c.count()
# Out:
# Invoice ID       1000
# Branch           1000
# City             1000
# Customer type    1000
# Gender           1000
# Product line     1000
# Unit price       1000
# Quantity         1000
# Tax 5%           1000
# Date             1000
# Time             1000
# Payment          1000
# cogs             1000
# Rating           1000
# Gross Revenue    1000
# Gross Profit     1000
# dtype: int64

# %%
c.replace(["Gender"])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6276\2706891485.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   c.replace(["Gender"])
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
# ...

# %%
ce = pd.DataFrame(c)

# %%
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
c["Gross Revenue"] = (c["Quantity"] * c["Unit price"])
print("\nDataFrame with Gross Revenue:")
c
# Out:
# DataFrame with Gross Revenue:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
c["Gross Profit"] = c["Gross Revenue"] - c["Unit price"]
print("\nDataFrame with Gross Revenue:")
c
# Out:
# DataFrame with Gross Revenue:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
product = c["Product line"].max()

# %%
product
# Out:
# 'Sports and travel'

# %%
Unit = c["Unit price"].max()

# %%
Unit
# Out:
# np.float64(99.96)

# %%
c.groupby("City").agg({"Gross Revenue": "max"})
# Out:
#            Gross Revenue
# City
# Mandalay           973.8
# Naypyitaw          993.0
# Yangon             989.8

# %%
c["Product line"].mode()
# Out:
# 0    Fashion accessories
# Name: Product line, dtype: object

# %%
c.groupby(["Gender","Product line"]).agg({"Product line": "count"})
# Out:
#                                Product line
# Gender Product line
# Female Electronic accessories            84
#        Fashion accessories               96
#        Food and beverages                90
#        Health and beauty                 65
#        Home and lifestyle                79
#        Sports and travel                 88
# Male   Electronic accessories            86
#        Fashion accessories               82
#        Food and beverages                84
#        Health and beauty                 87
#        Home and lifestyle                81
#        Sports and travel                 78

# %%
shpl = hpl["Product line"].sort_values(ascending = False)

# %%
shpl
# Out:
# Gender  Product line
# Female  Fashion accessories       96
#         Food and beverages        90
#         Sports and travel         88
# Male    Health and beauty         87
#         Electronic accessories    86
# Female  Electronic accessories    84
# Male    Food and beverages        84
#         Fashion accessories       82
#         Home and lifestyle        81
# Female  Home and lifestyle        79
# Male    Sports and travel         78
# Female  Health and beauty         64
# Name: Product line, dtype: int64

# %%
shpl.reset_index = True

# %%
shpl
# Out:
# Gender  Product line
# Female  Fashion accessories       96
#         Food and beverages        90
#         Sports and travel         88
# Male    Health and beauty         87
#         Electronic accessories    86
# Female  Electronic accessories    84
# Male    Food and beverages        84
#         Fashion accessories       82
#         Home and lifestyle        81
# Female  Home and lifestyle        79
# Male    Sports and travel         78
# Female  Health and beauty         64
# Name: Product line, dtype: int64

# %%
c.groupby("Customer type").agg({"Gross Revenue": "max"})
# Out:
#                Gross Revenue
# Customer type
# Member                 993.0
# Normal                 989.8

# %% [markdown]
# ### General Analicis

# %%
import matplotlib.pyplot as pl

# %%
c
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%       Date  \
# 0         Health and beauty       74.69       7.0  26.1415   1/5/2019
# 1    Electronic accessories       15.28       5.0   3.8200   3/8/2019
# ...

# %%
A = c.groupby (["Product line",]).agg({"Quantity": "sum"}).reset_index(["Product line",])

# %%
A
# Out:
#              Product line  Quantity
# 0  Electronic accessories     966.0
# 1     Fashion accessories     902.0
# 2      Food and beverages     952.0
# 3       Health and beauty     854.0
# 4      Home and lifestyle     911.0
# 5       Sports and travel     920.0

# %%
B = c.groupby (["City",]).agg({"Gross Revenue": "sum"}).reset_index(["City",])

# %%
B
# Out:
#         City  Gross Revenue
# 0   Mandalay      101140.64
# 1  Naypyitaw      104436.13
# 2     Yangon      101185.56

# %%
D = c.groupby (["Gender",]).agg({"Product line": "count"}).reset_index(["Gender",])

# %%
D
# Out:
#    Gender  Product line
# 0  Female           502
# 1    Male           498

# %%
D1

# %%
E = c.groupby (["Customer type",]).agg({"Gross Revenue": "sum"}).reset_index(["Customer type",])

# %%
E
# Out:
#   Customer type  Gross Revenue
# 0        Member      155501.46
# 1        Normal      151260.87
