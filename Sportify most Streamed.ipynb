# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
pd.read_csv("Spotify Most Streamed Songs.csv")
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
st = pd.read_csv("Spotify Most Streamed Songs.csv")

# %%
st.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# ...

# %%
st [st["streams"] == "73513683" ]
# Out:
#                track_name      artist(s)_name  artist_count  released_year  \
# 950  A Veces (feat. Feid)  Feid, Paulo Londra             2           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 950              11             3                   573                  0
#
#       streams  in_apple_playlists  ...  key   mode  danceability_% valence_%  \
# 950  73513683                   2  ...   C#  Major              80        81
#
#      energy_% acousticness_% instrumentalness_%  liveness_%  speechiness_%  \
# 950        67              4                  0           8              6
#
#      cover_url
# 950  Not Found
#
# [1 rows x 25 columns]

# %%
st [st["streams"] < "73513683"]
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# 5                               Sprinter   Dave, Central Cee             2
# ..                                   ...                 ...           ...
# 944                        The Astronaut                 Jin             1
# 946                           Broke Boys    Drake, 21 Savage             2
# 947                        The Great War        Taylor Swift             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 951                        En La De Ella  Feid, Sech, Jhayco             3
#
# ...

# %%
st[(st["in_spotify_charts"]>72) &  (st["released_day"] <15)]
# Out:
#                                            track_name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 5                                            Sprinter
# 12                                            Flowers
# 13                                           Daylight
# 15                                          Kill Bill
# 17  What Was I Made For? [From The Motion Picture ...
# 22                                   I Wanna Be Yours
# 24  Popular (with Playboi Carti & Madonna) - The I...
# 30                                               Rush
# 32                                           Creepin'
# 41      Sunflower - Spider-Man: Into the Spider-Verse
# 46                                    I Ain't Worried
#
#                          artist(s)_name  artist_count  released_year  \
# 0                      Latto, Jung Kook             2           2023
# 5                     Dave, Central Cee             2           2023
# ...

# %%
st.mode()
# Out:
#                                track_name artist(s)_name  artist_count  \
# 0                         About Damn Time   Taylor Swift           1.0
# 1                                Daylight            NaN           NaN
# 2                             Die For You            NaN           NaN
# 3                                 Flowers            NaN           NaN
# 4  Let It Snow! Let It Snow! Let It Snow!            NaN           NaN
# 5                                Miss You            NaN           NaN
# 6                                    Numb            NaN           NaN
# 7                                    SNAP            NaN           NaN
# 8                        SPIT IN MY FACE!            NaN           NaN
# 9                          Take My Breath            NaN           NaN
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2022.0             1.0           1.0                    86
# ...

# %%
st["vibers"] = None

# %%
st
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
st.isnull()
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
st.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
st.groupby("mode").count()
# Out:
#        track_name  artist(s)_name  artist_count  released_year  \
# mode
# Major         550             550           550            550
# Minor         403             403           403            403
#
#        released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# mode
# Major             550           550                   550                550
# Minor             403           403                   403                403
#
#        streams  in_apple_playlists  ...  key  danceability_%  valence_%  \
# mode                                ...
# Major      550                 550  ...  475             550        550
# Minor      403                 403  ...  383             403        403
#
#        energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# mode
# Major       550             550                 550         550
# Minor       403             403                 403         403
#
#        speechiness_%  cover_url  vibers
# mode
# ...

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
st.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...   mode  \
# ...

# %%
st[st["artist(s)_name"] == "Taylor Swift"]
# Out:
#                                             track_name artist(s)_name  \
# 3                                         Cruel Summer   Taylor Swift
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...   Taylor Swift
# 33                                           Anti-Hero   Taylor Swift
# 37                                         Blank Space   Taylor Swift
# 38                                               Style   Taylor Swift
# 59                                            cardigan   Taylor Swift
# 66                                               Karma   Taylor Swift
# 69                        Enchanted (Taylor's Version)   Taylor Swift
# 83                 Back To December (Taylor's Version)   Taylor Swift
# 93                                    Donï¿½ï¿½ï¿½t Bl   Taylor Swift
# 100                                              Lover   Taylor Swift
# 113                            Mine (Taylor's Version)   Taylor Swift
# ...

# %%
st[(st["artist(s)_name"] == "Taylor Swift")][["artist(s)_name","released_year","streams",]]
# Out:
#     artist(s)_name  released_year     streams
# 3     Taylor Swift           2019   800840817
# 21    Taylor Swift           2023    52135248
# 33    Taylor Swift           2022   999748277
# 37    Taylor Swift           2014  1355959075
# 38    Taylor Swift           2014   786181836
# 59    Taylor Swift           2020   812019557
# 66    Taylor Swift           2022   404562836
# 69    Taylor Swift           2023    39578178
# 83    Taylor Swift           2023    39228929
# 93    Taylor Swift           2017   685032533
# 100   Taylor Swift           2012   882831184
# 113   Taylor Swift           2023    36912123
# 119   Taylor Swift           2020   607123776
# 163   Taylor Swift           2010   621660989
# 176   Taylor Swift           2014  1113838873
# 191   Taylor Swift           2021   350381515
# 193   Taylor Swift           2023    30343206
# 206   Taylor Swift           2023    68616963
# 237   Taylor Swift           2022   488386797
# ...

# %%
st["streams"] [7]
# Out:
# '58149378'

# %%
st[1:10]
# Out:
#         track_name              artist(s)_name  artist_count  released_year  \
# 1             LALA                 Myke Towers             1           2023
# 2          vampire              Olivia Rodrigo             1           2023
# 3     Cruel Summer                Taylor Swift             1           2019
# 4   WHERE SHE GOES                   Bad Bunny             1           2023
# 5         Sprinter           Dave, Central Cee             2           2023
# 6  Ella Baila Sola  Eslabon Armado, Peso Pluma             2           2023
# 7         Columbia                     Quevedo             1           2023
# 8         fukumean                       Gunna             1           2023
# 9  La Bebe - Remix       Peso Pluma, Yng Lvcas             2           2023
#
#    released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 1               3            23                  1474                 48
# ...

# %%
st.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...   mode  \
# ...

# %%
st.groupby("mode").agg ({"streams": ["sum","count"]})
# Out:
#                                                  streams
#                                                      sum count
# mode
# Major  1413817031337162861400039748008408171837062345...   550
# Minor  3032363227259801129521731555363406750567143858...   403

# %%
st
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
st.sort_values("streams", ascending = False)
# Out:
#                                   track_name      artist(s)_name  \
# 574      Love Grows (Where My Rosemary Goes)   Edison Lighthouse
# 33                                 Anti-Hero        Taylor Swift
# 625                                   Arcade     Duncan Laurence
# 253                            Glimpse of Us                Joji
# 455                           Seek & Destroy                 SZA
# ..                                       ...                 ...
# 366                                  Revenge        XXXTENTACION
# 744                                 Right On            Lil Baby
# 515                             Best Friends          The Weeknd
# 500                               ýýýabcdefu               Gayle
# 301  Arcï¿½ï¿½ngel: Bzrp Music Sessions, Vol  Arcangel, Bizarrap
#
#      artist_count  released_year  released_month  released_day  \
# 574             1           1970               1             1
# ...

# %%
C= st.sort_values("streams", ascending = True)

# %%
C.streams.max()
# Out:
# 'BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3'
