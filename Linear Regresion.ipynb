# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sk = pd.read_csv("train.csv")

# %%
sk.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
### Unique Values under Item_Fat _Content
sk.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
sk.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
sk.Item_Identifier.unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
sk.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
sk.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
sk.Item_Fat_Content.replace({"low fat": "Low Fat", "LF": "Low Fat", "reg": "Regular"}, inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16704\1509355804.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk.Item_Fat_Content.replace({"low fat": "Low Fat", "LF": "Low Fat", "reg": "Regular"}, inplace = True)

# %%
sk.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
### Check for dublicated Values!
sk.duplicated().sum()
# Out:
# np.int64(0)

# %%
sk.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
sk.Item_Weight.isnull().sum()/len(sk)* 100
# Out:
# np.float64(17.165317376510618)

# %%
len(sk)
# Out:
# 8523

# %%
sk.Outlet_Size.isnull().sum()/len(sk)* 100
# Out:
# np.float64(28.27642848762173)

# %%
sk.fillna({"Outlet_Size":"Medium"})
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sk
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
a= {"Low Fat": 0, "Regular": 1}
sk.Item_Fat_Content = sk.Item_Fat_Content.map(a)

# %%
sk
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 0         0.016047
# 1              DRC01        5.920                 1         0.019278
# 2              FDN15       17.500                 0         0.016760
# 3              FDX07       19.200                 1         0.000000
# 4              NCD19        8.930                 0         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 0         0.056783
# 8519           FDS36        8.380                 1         0.046982
# 8520           NCJ29       10.600                 0         0.035186
# 8521           FDN46        7.210                 1         0.145221
# 8522           DRG01       14.800                 0         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sk.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
b = {"Tier 1": 0, "Tier 2": 1, "Tier 3": 2}
sk.Outlet_Location_Type = sk.Outlet_Location_Type.map(b)

# %%
sk.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 0         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                       1999      Medium                     0
# 1                       2009      Medium                     2
# ...

# %%
## Dropping the item type column
sk.drop("Item_Type", axis= 1, inplace = True)

# %%
sk.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30                 0         0.016047  249.8092
# 1           DRC01         5.92                 1         0.019278   48.2692
# 2           FDN15        17.50                 0         0.016760  141.6180
# 3           FDX07        19.20                 1         0.000000  182.0950
# 4           NCD19         8.93                 0         0.000000   53.8614
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 3            OUT010                       1998         NaN
# 4            OUT013                       1987        High
#
#    Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                     0  Supermarket Type1          3735.1380
# ...

# %%
sk.fillna({"Outlet_Size":"Medium"}, inplace = True)

# %%
sk
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 0         0.016047
# 1              DRC01        5.920                 1         0.019278
# 2              FDN15       17.500                 0         0.016760
# 3              FDX07       19.200                 1         0.000000
# 4              NCD19        8.930                 0         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 0         0.056783
# 8519           FDS36        8.380                 1         0.046982
# 8520           NCJ29       10.600                 0         0.035186
# 8521           FDN46        7.210                 1         0.145221
# 8522           DRG01       14.800                 0         0.044878
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# ...

# %%
sk.drop("Outlet_Identifier", axis= 1, inplace = True)

# %%
sk.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30                 0         0.016047  249.8092
# 1           DRC01         5.92                 1         0.019278   48.2692
# 2           FDN15        17.50                 0         0.016760  141.6180
# 3           FDX07        19.20                 1         0.000000  182.0950
# 4           NCD19         8.93                 0         0.000000   53.8614
#
#    Outlet_Establishment_Year Outlet_Size  Outlet_Location_Type  \
# 0                       1999      Medium                     0
# 1                       2009      Medium                     2
# 2                       1999      Medium                     0
# 3                       1998      Medium                     2
# 4                       1987        High                     2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# ...

# %%
c = {"Medium": 1, "High": 2, "Small": 0}
sk.Outlet_Size = sk.Outlet_Size.map(c)

# %%
sk.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30                 0         0.016047  249.8092
# 1           DRC01         5.92                 1         0.019278   48.2692
# 2           FDN15        17.50                 0         0.016760  141.6180
# 3           FDX07        19.20                 1         0.000000  182.0950
# 4           NCD19         8.93                 0         0.000000   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                       1999            1                     0
# 1                       2009            1                     2
# 2                       1999            1                     0
# 3                       1998            1                     2
# 4                       1987            2                     2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# ...

# %%
d = {"Supermarket Type1": 0, "Supermarket Type2": 1, "Supermarket Type3": 2,"Grocery Store":3}
sk.Outlet_Type = sk.Outlet_Type.map(d)

# %%
sk
# Out:
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 0         0.016047
# 1              DRC01        5.920                 1         0.019278
# 2              FDN15       17.500                 0         0.016760
# 3              FDX07       19.200                 1         0.000000
# 4              NCD19        8.930                 0         0.000000
# ...              ...          ...               ...              ...
# 8518           FDF22        6.865                 0         0.056783
# 8519           FDS36        8.380                 1         0.046982
# 8520           NCJ29       10.600                 0         0.035186
# 8521           FDN46        7.210                 1         0.145221
# 8522           DRG01       14.800                 0         0.044878
#
#       Item_MRP  Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# ...

# %%
sk.drop("Item_Identifier", axis = 1, inplace = True)

# %%
sk
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           9.300                 0         0.016047  249.8092
# 1           5.920                 1         0.019278   48.2692
# 2          17.500                 0         0.016760  141.6180
# 3          19.200                 1         0.000000  182.0950
# 4           8.930                 0         0.000000   53.8614
# ...           ...               ...              ...       ...
# 8518        6.865                 0         0.056783  214.5218
# 8519        8.380                 1         0.046982  108.1570
# 8520       10.600                 0         0.035186   85.1224
# 8521        7.210                 1         0.145221  103.1332
# 8522       14.800                 0         0.044878   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                          1999            1                     0
# 1                          2009            1                     2
# ...

# %%
sk.corr()
# Out:
#                            Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight                   1.000000         -0.023238        -0.014048
# Item_Fat_Content             -0.023238          1.000000         0.047314
# Item_Visibility              -0.014048          0.047314         1.000000
# Item_MRP                      0.027141          0.006063        -0.001315
# Outlet_Establishment_Year    -0.011588          0.003151        -0.074834
# Outlet_Size                   0.007749          0.000622        -0.069309
# Outlet_Location_Type          0.004715         -0.001598        -0.028099
# Outlet_Type                   0.003890         -0.001967         0.223308
# Item_Outlet_Sales             0.014123          0.018719        -0.128625
#
#                            Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# Item_Weight                0.027141                  -0.011588     0.007749
# ...

# %% [markdown]
# ### Feature Selection

# %%
sk = sk[["Outlet_Location_Type", "Outlet_Size", "Outlet_Type", "Item_Outlet_Sales", "Item_MRP"]]

# %%
sk.head()
# Out:
#    Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_Outlet_Sales  Item_MRP
# 0                     0            1            0          3735.1380  249.8092
# 1                     2            1            1           443.4228   48.2692
# 2                     0            1            0          2097.2700  141.6180
# 3                     2            1            3           732.3800  182.0950
# 4                     2            2            0           994.7052   53.8614

# %%
import seaborn as sns

# %%
sns.pairplot(sk)

# %%
## Checking for Outliers
plt.boxplot(sk["Item_Outlet_Sales"])
plt.show()

# %%
## Handling Outliers Using Logrithims
np.log(sk.Item_Outlet_Sales)
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       6.596300
# 4       6.902446
#           ...
# 8518    7.929625
# 8519    6.308617
# 8520    7.084322
# 8521    7.520558
# 8522    6.640751
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
sk.Item_Outlet_Sales = np.log(sk.Item_Outlet_Sales)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16704\2946745403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sk.Item_Outlet_Sales = np.log(sk.Item_Outlet_Sales)

# %%
plt.figure(figsize = (7,7))
plt.subplot(2,2,1)
plt.boxplot(sk.bedrooms)
plt.xlabel("bedrooms")
plt.subplot(2,2,2)
plt.boxplot(sk.barhrooms)
plt.xlabel("bathrooms")
plt.subplot(2,2,3)
plt.boxplot(sk.sqft_living)
plt.xlabel("sqft_living")
plt.subplot(2,2,4)
plt.boxplot(sk.sqft_above)
plt.xlabel("sqft_above")
plt.show()

# %%
a = sk.Item_Outlet_Sales > 5
sk = sk[a]

# %%
sk
# Out:
#       Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_Outlet_Sales  \
# 0                        0            1            0           8.225540
# 1                        2            1            1           6.094524
# 2                        0            1            0           7.648392
# 3                        2            1            3           6.596300
# 4                        2            2            0           6.902446
# ...                    ...          ...          ...                ...
# 8518                     2            2            0           7.929625
# 8519                     1            1            0           6.308617
# 8520                     1            0            0           7.084322
# 8521                     2            1            1           7.520558
# 8522                     0            0            0           6.640751
#
#       Item_MRP
# 0     249.8092
# 1      48.2692
# 2     141.6180
# 3     182.0950
# 4      53.8614
# ...

# %%
plt.boxplot(sk["Item_Outlet_Sales"])
plt.show()

# %%
sk.head()
# Out:
#    Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_Outlet_Sales  Item_MRP
# 0                     0            1            0           8.225540  249.8092
# 1                     2            1            1           6.094524   48.2692
# 2                     0            1            0           7.648392  141.6180
# 3                     2            1            3           6.596300  182.0950
# 4                     2            2            0           6.902446   53.8614

# %%
X= sk.drop("Item_Outlet_Sales", axis = 1)
X
# Out:
#       Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_MRP
# 0                        0            1            0  249.8092
# 1                        2            1            1   48.2692
# 2                        0            1            0  141.6180
# 3                        2            1            3  182.0950
# 4                        2            2            0   53.8614
# ...                    ...          ...          ...       ...
# 8518                     2            2            0  214.5218
# 8519                     1            1            0  108.1570
# 8520                     1            0            0   85.1224
# 8521                     2            1            1  103.1332
# 8522                     0            0            0   75.4670
#
# [8254 rows x 4 columns]

# %%
Y = sk["Item_Outlet_Sales"]

# %%
Y
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       6.596300
# 4       6.902446
#           ...
# 8518    7.929625
# 8519    6.308617
# 8520    7.084322
# 8521    7.520558
# 8522    6.640751
# Name: Item_Outlet_Sales, Length: 8254, dtype: float64

# %%
print (X.shape)
print (Y.shape)
# Out:
# (8254, 4)
# (8254,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Initialize the linear Regression model
LR = LinearRegression()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state = 10)

# %%
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
LR.predict(X_test)
# Out:
# array([7.77695652, 7.31412429, 7.92648958, ..., 8.59865866, 7.73678528,
#        7.56666485])

# %%
Y_test
# Out:
# 4866    7.402775
# 142     7.670371
# 7178    7.950258
# 8416    6.830293
# 5995    7.181051
#           ...
# 439     8.188869
# 1833    7.593584
# 7635    7.954709
# 1649    8.356349
# 6453    7.608231
# Name: Item_Outlet_Sales, Length: 2064, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
predicted_values = LR.predict(X_test)

# %%
mean_squared_error(Y_test, predicted_values)
# Out:
# np.float64(0.4830565130590205)

# %%
## Intercept Model
LR.intercept_
# Out:
# np.float64(6.361333608736395)

# %%
plt.scatter(Y_test, predicted_values)
plt.plot(Y_test, Y_test, c = "red")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %%
LR.predict([[2,2,0,53.8614]])
# Out:
# C:\Users\HP\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.09336018])
